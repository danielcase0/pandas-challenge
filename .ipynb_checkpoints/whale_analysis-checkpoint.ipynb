# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
# import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns

# Set the file path
whale_returns_csvpath = Path('./Resources/whale_returns.csv')

# %%
# Create a Pandas dataframe from a csv file

# Option 1: Read the file, explore it, and set the index later
# whale_returns_df = pd.read_csv(whale_returns_csvpath)

# %%
# Exploring the data

# Dimensions of the dataset
# whale_returns_df.shape
# Output: (1060, 5)

# Get the first 5 rows from the dataframe
# whale_returns_df.head()

# Get the number of records in the dataframe
# whale_returns_df.count()

# Check Data Types
# whale_returns_df.dtypes

# %%
# Set the index to be the date
# whale_returns_df.set_index(whale_returns_df['Date'], inplace=True)

# Drop the redundant date column
# whale_returns_df.drop(columns=['Date'], inplace=True)

# whale_returns_df.head()

# %%
# Create a Pandas dataframe from a csv file

# Option 2: Read the file and set the index now
whale_returns_df = pd.read_csv(whale_returns_csvpath, index_col="Date", parse_dates=True)

# %%
# Count nulls
whale_returns_df.isnull().mean() * 100
# Out:
# SOROS FUND MANAGEMENT LLC      0.09434
# PAULSON & CO.INC.              0.09434
# TIGER GLOBAL MANAGEMENT LLC    0.09434
# BERKSHIRE HATHAWAY INC         0.09434
# dtype: float64

# %%
# Drop nulls
whale_returns_df.dropna(inplace=True)

# %%
# Sort the index
whale_returns_df.sort_index(ascending=True, inplace=True)

whale_returns_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns

# Set the file path
algorithmic_daily_returns_csvpath = Path('./Resources/algo_returns.csv')

# %%
# Create a Pandas dataframe from a csv file

# Option 1: Read the file, explore it, and set the index later
# algorithmic_daily_returns_df = pd.read_csv(algorithmic_daily_returns_csvpath)

# %%
# Exploring the data

# Dimensions of the dataset
# algorithmic_daily_returns_df.shape
# Output: (1241, 3)

# get the first 5 rows from the dataframe
# algorithmic_daily_returns_df.head()

# get the number of records in the dataframe
# algorithmic_daily_returns_df.count()

# Check Data Types
# algorithmic_daily_returns_df.dtypes

# %%
# Set the index to be the date
# algorithmic_daily_returns_df.set_index(algorithmic_daily_returns_df['Date'], inplace=True)

# Drop the redundant date column
# algorithmic_daily_returns_df.drop(columns=['Date'], inplace=True)

# algorithmic_daily_returns_df.head()

# %%
# Create a Pandas dataframe from a csv file

# Option 2: Read the file and set the index now
algorithmic_daily_returns_df = pd.read_csv(algorithmic_daily_returns_csvpath, index_col="Date", parse_dates=True)

# %%
# Count nulls
algorithmic_daily_returns_df.isnull().mean() * 100
# Out:
# Algo 1    0.000000
# Algo 2    0.483481
# dtype: float64

# %%
# Drop nulls
algorithmic_daily_returns_df.dropna(inplace=True)

# %%
# Sort the index
algorithmic_daily_returns_df.sort_index(ascending=True, inplace=True)

algorithmic_daily_returns_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices

# Set the file path
sp500_returns_csvpath = Path('./Resources/sp500_history.csv')

# %%
# Create a Pandas dataframe from a csv file

# Option 1: Read the file, explore it, and set the index later
# sp500_returns_df = pd.read_csv(sp500_returns_csvpath)

# %%
# Exploring the data

# Dimensions of the dataset
# sp500_returns_df.shape
# Output: (1649, 2)

# get the first 5 rows from the dataframe
# sp500_returns_df.head()

# get the number of records in the dataframe
# sp500_returns_df.count()

# get the number of records in the dataframe
# sp500_returns_df.count()

# %%
# Fix Data Types
# Convert the Date to a datetime
# sp500_returns_df['Date'] = pd.to_datetime(sp500_returns_df['Date'], format="%Y-%m-%d")
# sp500_returns_df['Date'] = pd.to_datetime(sp500_returns_df['Date'])

# Set the index to be the date
# sp500_returns_df.set_index(sp500_returns_df['Date'], inplace=True)

# Drop the redundant date column
# sp500_returns_df.drop(columns=['Date'], inplace=True)

# sp500_returns_df.head()

# %%
# Create a Pandas dataframe from a csv file

# Option 2: Read the file and set the index now
sp500_returns_df = pd.read_csv(sp500_returns_csvpath, index_col="Date", parse_dates=True)
# Out:
# C:\Users\Daniel\AppData\Local\Temp\ipykernel_17824\738745340.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500_returns_df = pd.read_csv(sp500_returns_csvpath, index_col="Date", parse_dates=True)

# %%
# Check Data Types
sp500_returns_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
# Remove the dollar signs from Close
sp500_returns_df["Close"] = sp500_returns_df["Close"].str.replace("$", "")

# Cast the close column as a float with two decimal places
# sp500_returns_df['Close'] = pd.to_numeric(sp500_returns_df['Close'], downcast='float').round(2)
sp500_returns_df['Close'] = sp500_returns_df['Close'].astype(float).round(2)

# Recheck Data Types
# sp500_returns_df.dtypes
# sp500_returns_df.head()

# %%
# Sort the index ascending so the daily returns are in the correct order
sp500_returns_df.sort_index(ascending=True, inplace=True)

# Calculate Daily Returns
sp500_daily_returns = sp500_returns_df.pct_change()
# sp500_daily_returns.head()

# %%
# Drop nulls
sp500_daily_returns.dropna(inplace=True)
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.columns = ['S&P 500 Close']
sp500_daily_returns.head()
# Out:
#             S&P 500 Close
# Date
# 2012-10-02       0.000872
# 2012-10-03       0.003624
# 2012-10-04       0.007174
# 2012-10-05      -0.000322
# 2012-10-08      -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df = pd.concat([whale_returns_df, algorithmic_daily_returns_df, sp500_daily_returns], axis="columns", join="inner")
combined_df.head(10)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# 2015-03-10                  -0.010263           -0.005341
# 2015-03-11                   0.004012            0.005163
# 2015-03-12                   0.008265            0.010272
# 2015-03-13                  -0.002497           -0.001428
# 2015-03-16                   0.007901            0.003583
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_df.plot(figsize=(20,10), title="Daily Returns").margins(x=0.025)

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns_df = (1 + combined_df).cumprod() - 1

# Plot cumulative returns
cumulative_returns_df.plot(figsize=(20,10), title="Cumulative Returns").margins(x=0.025)

# %%
# Cumulative returns outcome
cumulative_returns_df.tail(1)
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2019-04-23                   0.164568           -0.220354
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2019-04-23                    -0.138811                0.553401  0.934691
#
#               Algo 2  S&P 500 Close
# Date
# 2019-04-23  0.269247       0.385517

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.plot.box(figsize=(20,10), title="Daily Returns")
# Out:
# <Axes: title={'center': 'Daily Returns'}>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std_df = combined_df.std()

daily_std_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.007895
# PAULSON & CO.INC.              0.007023
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007620
# Algo 2                         0.008342
# S&P 500 Close                  0.008554
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
# This is already calculated in the daily_std_df
print(f"The standard deviation of the S&P 500 is {round(daily_std_df['S&P 500 Close'] * 100, 2)}%.")
# Out:
# The standard deviation of the S&P 500 is 0.86%.

# %%
# Determine which portfolios are riskier than the S&P 500

print("The portfolios that are riskier than the S&P 500 are:")

for row_number in range(0, len(daily_std_df)):
    if daily_std_df[row_number] > daily_std_df['S&P 500 Close']:
        print(daily_std_df.index[row_number])
# Out:
# The portfolios that are riskier than the S&P 500 are:
# TIGER GLOBAL MANAGEMENT LLC
# BERKSHIRE HATHAWAY INC

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std_df = daily_std_df * np.sqrt(252)
annualized_std_df
# Out:
# SOROS FUND MANAGEMENT LLC      0.125335
# PAULSON & CO.INC.              0.111488
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# BERKSHIRE HATHAWAY INC         0.205077
# Algo 1                         0.120967
# Algo 2                         0.132430
# S&P 500 Close                  0.135786
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
rolling_21_std_df = combined_df.rolling(window=21).std()

# Plot the rolling standard deviation
rolling_21_std_df.plot(figsize=(20,10), title="21-day Rolling Standard Deviation").margins(x=0.025)

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation_df = combined_df.corr()

# Display the correlation matrix
sns.heatmap(correlation_df, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
# Chosen portfolio: Algo 2
covariance_algo2_sp500 = combined_df['Algo 2'].cov(combined_df['S&P 500 Close'])
covariance_algo2_sp500
# Out:
# 6.12793237414499e-05

# %%
# Calculate variance of S&P 500
variance_sp500 = combined_df['S&P 500 Close'].var()
variance_sp500
# Out:
# 7.316632424648712e-05

# %%
# Computing beta
algo2_beta = covariance_algo2_sp500 / variance_sp500
algo2_beta
# Out:
# 0.8375345402757753

# %%
# Plot beta trend
# Assume a 21-day rolling window

# 21-day rolling covariance
rolling_21_covariance_algo2_sp500 = combined_df['Algo 2'].rolling(window=21).cov(combined_df['S&P 500 Close'])

# 21-day rolling variance
rolling_21_variance = combined_df['S&P 500 Close'].rolling(window=21).var()

# 21-day rolling beta
rolling_21_beta = rolling_21_covariance_algo2_sp500 / rolling_21_variance

# Drop null values
rolling_21_beta.dropna(inplace=True)

rolling_21_beta.plot(figsize=(20,10), title="21-day Rolling Beta for Algo 2")
# Out:
# <Axes: title={'center': '21-day Rolling Beta for Algo 2'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
ewm_df = combined_df.ewm(halflife=21).std()
ewm_df.dropna(inplace=True)
ewm_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
# 2015-03-10                   0.005816            0.004707
# ...                               ...                 ...
# 2019-04-16                   0.007632            0.006846
# 2019-04-17                   0.007547            0.006846
# 2019-04-18                   0.007424            0.006737
# 2019-04-22                   0.007336            0.006764
# 2019-04-23                   0.007294            0.006682
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-04                     0.001441                0.007624  0.004700
# 2015-03-05                     0.002478                0.007020  0.004162
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_df.mean() * 252) / (daily_std_df * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.356417
# PAULSON & CO.INC.             -0.483570
# TIGER GLOBAL MANAGEMENT LLC   -0.121060
# BERKSHIRE HATHAWAY INC         0.621810
# Algo 1                         1.378648
# Algo 2                         0.501364
# S&P 500 Close                  0.648267
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot.bar(title='Sharpe Ratios')
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Outcomes:
# - Soros Fund Management LLC: 16.46% return, 0.36 Sharpe Ratio
# - Paulson & Co. Inc.: -22.04% return, -0.48 Sharpe Ratio
# - Tiger Global Management LLC: -13.88% return, -0.12 Sharpe Ratio
# - Berkshire Hathaway: 55.34% return, 0.62 Sharpe Ratio
# - S&P 500: 38.55% return, 0.64 Sharpe Ratio
# - Algo 1: 93.47% return, 1.38 Sharpe Ratio
# - Algo 2: 26.92% return, 0.50 Sharpe Ratio
#
# Algo 1 significantly outperformed the market and the whales' portfolios.  Not only did it offer the best performance (93.47% return), but it also offered the best risk-adjusted returns (1.38 Sharpe ratio).
#
# Algo 2 fell somewhere in the middle of the group.  It underperformed the market (26.92% return vs the S&P's 38.55% return), but it did beat 3/4 whales' portfolios.  Additionally, it had a worse risk-adjusted returns than the market, but it had better risk-adjusted returns than 3/4 whales' portfolios.
#
# In the end, Algo 1 is the clear winner.  Although Algo 2 underperformed the market, it was still better than several of the whales' portfolios during the same time period.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from the 1st stock
# Set the file path
aapl_returns_csvpath = Path('./Resources/aapl_historical.csv')

# Read the file and set the index
aapl_returns_df = pd.read_csv(aapl_returns_csvpath, index_col="Date", parse_dates=True)

# Drop the symbol column and rename the close column to the ticker symbol
aapl_returns_df.drop(columns=['Symbol'], inplace=True)
aapl_returns_df.columns = ['AAPL']

aapl_returns_df.head()
# Out:
#               AAPL
# Date
# 2022-01-03  182.01
# 2022-01-04  179.70
# 2022-01-05  174.92
# 2022-01-06  172.00
# 2022-01-07  172.17

# %%
# Reading data from the 2nd stock
# Set the file path
axp_returns_csvpath = Path('./Resources/axp_historical.csv')

# Read the file and set the index
axp_returns_df = pd.read_csv(axp_returns_csvpath, index_col="Date", parse_dates=True)

# Drop the symbol column and rename the close column to the ticker symbol
axp_returns_df.drop(columns=['Symbol'], inplace=True)
axp_returns_df.columns = ['AXP']

axp_returns_df.head()
# Out:
#                AXP
# Date
# 2022-01-03  168.21
# 2022-01-04  173.61
# 2022-01-05  171.76
# 2022-01-06  172.90
# 2022-01-07  174.38

# %%
# Reading data from the 3rd stock
# Set the file path
gs_returns_csvpath = Path('./Resources/gs_historical.csv')

# Read the file and set the index
gs_returns_df = pd.read_csv(gs_returns_csvpath, index_col="Date", parse_dates=True)

# Drop the symbol column and rename the close column to the ticker symbol
gs_returns_df.drop(columns=['Symbol'], inplace=True)
gs_returns_df.columns = ['GS']

gs_returns_df.head()
# Out:
#                 GS
# Date
# 2022-01-03  395.33
# 2022-01-04  407.48
# 2022-01-05  398.63
# 2022-01-06  396.93
# 2022-01-07  397.51

# %%
# Reading data from the 4th stock
# Set the file path
ko_returns_csvpath = Path('./Resources/ko_historical.csv')

# Read the file and set the index
ko_returns_df = pd.read_csv(ko_returns_csvpath, index_col="Date", parse_dates=True)

# Drop the symbol column and rename the close column to the ticker symbol
ko_returns_df.drop(columns=['Symbol'], inplace=True)
ko_returns_df.columns = ['KO']

ko_returns_df.head()
# Out:
#                KO
# Date
# 2022-01-03  59.30
# 2022-01-04  60.29
# 2022-01-05  60.79
# 2022-01-06  60.47
# 2022-01-07  60.33

# %%
# Reading data from the 5th stock
# Set the file path
pltr_returns_csvpath = Path('./Resources/pltr_historical.csv')

# Read the file and set the index
pltr_returns_df = pd.read_csv(pltr_returns_csvpath, index_col="Date", parse_dates=True)

# Drop the symbol column and rename the close column to the ticker symbol
pltr_returns_df.drop(columns=['Symbol'], inplace=True)
pltr_returns_df.columns = ['PLTR']

pltr_returns_df.head()
# Out:
#              PLTR
# Date
# 2022-01-03  18.53
# 2022-01-04  18.17
# 2022-01-05  16.96
# 2022-01-06  16.74
# 2022-01-07  16.56

# %%
# Reading data from the S&P 500
# Set the file path
sp500_returns_custom_range_csvpath = Path('./Resources/sp500_historical.csv')

# Read the file and set the index
sp500_returns_custom_range_returns_df = pd.read_csv(sp500_returns_custom_range_csvpath, index_col="Date", parse_dates=True)

# Drop the symbol column and rename the close column to the ticker symbol
sp500_returns_custom_range_returns_df.drop(columns=['Symbol'], inplace=True)
sp500_returns_custom_range_returns_df.columns = ['S&P 500']

sp500_returns_custom_range_returns_df.head()
# Out:
#             S&P 500
# Date
# 2022-01-03  4796.56
# 2022-01-04  4793.54
# 2022-01-05  4700.58
# 2022-01-06  4696.05
# 2022-01-07  4677.03

# %%
# Combine all stocks in a single DataFrame
stock_porfolio_df = pd.concat([aapl_returns_df, axp_returns_df, gs_returns_df, ko_returns_df, pltr_returns_df, sp500_returns_custom_range_returns_df], axis="columns", join="inner")
stock_porfolio_df.head(10)
# Out:
#               AAPL     AXP      GS     KO   PLTR  S&P 500
# Date
# 2022-01-03  182.01  168.21  395.33  59.30  18.53  4796.56
# 2022-01-04  179.70  173.61  407.48  60.29  18.17  4793.54
# 2022-01-05  174.92  171.76  398.63  60.79  16.96  4700.58
# 2022-01-06  172.00  172.90  396.93  60.47  16.74  4696.05
# 2022-01-07  172.17  174.38  397.51  60.33  16.56  4677.03
# 2022-01-10  172.19  173.74  399.17  60.43  16.50  4670.29
# 2022-01-11  175.08  175.38  403.05  60.45  16.89  4713.07
# 2022-01-12  175.53  174.47  390.31  60.54  16.72  4726.35
# 2022-01-13  172.19  173.29  390.80  60.90  16.01  4659.03
# 2022-01-14  173.07  168.40  380.94  61.39  16.01  4662.85

# %%
# Calculate daily returns
stock_porfolio_daily_returns = stock_porfolio_df.pct_change()

# Drop NAs
stock_porfolio_daily_returns.dropna(inplace=True)

# Display sample data
stock_porfolio_daily_returns.plot(figsize=(20,10), title="Daily Returns").margins(x=0.025)

# %%
# Calculate cumulative returns of all portfolios
stock_portfolio_cumulative_returns_df = (1 + stock_porfolio_daily_returns).cumprod() - 1

# Plot cumulative returns
stock_portfolio_cumulative_returns_df.plot(figsize=(20,10), title="Cumulative Returns").margins(x=0.025)

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
# Note that the sixth column is the S&P 500 index
weights = [1/5, 1/5, 1/5, 1/5, 1/5, 0]

# Calculate portfolio return
equal_weight_returns = stock_porfolio_daily_returns.dot(weights)

# Display sample data
equal_weight_returns.head()
# Out:
# Date
# 2022-01-04    0.009482
# 2022-01-05   -0.023455
# 2022-01-06   -0.006511
# 2022-01-07   -0.000412
# 2022-01-10   -0.000269
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
daily_returns_with_portfolio_df = pd.concat([stock_porfolio_daily_returns, equal_weight_returns], axis="columns", join="inner")

# Rename the last column to be the portfolio returns
daily_returns_with_portfolio_df.columns.values[-1]='Portfolio'

daily_returns_with_portfolio_df.head()
# Out:
#                 AAPL       AXP        GS        KO      PLTR   S&P 500  \
# Date
# 2022-01-04 -0.012692  0.032103  0.030734  0.016695 -0.019428 -0.000630
# 2022-01-05 -0.026600 -0.010656 -0.021719  0.008293 -0.066593 -0.019393
# 2022-01-06 -0.016693  0.006637 -0.004265 -0.005264 -0.012972 -0.000964
# 2022-01-07  0.000988  0.008560  0.001461 -0.002315 -0.010753 -0.004050
# 2022-01-10  0.000116 -0.003670  0.004176  0.001658 -0.003623 -0.001441
#
#             Portfolio
# Date
# 2022-01-04   0.009482
# 2022-01-05  -0.023455
# 2022-01-06  -0.006511
# 2022-01-07  -0.000412
# 2022-01-10  -0.000269

# %%
# Checking the cumulative return of the porfolio

# Calculate the cumulative returns of the portfolio
stock_portfolio_cumulative_returns_v2_df = (1 + daily_returns_with_portfolio_df).cumprod() - 1

# Plot the cumulative returns
stock_portfolio_cumulative_returns_v2_df.plot(figsize=(20,10), title="Cumulative Returns").margins(x=0.025)

# print(stock_portfolio_cumulative_returns_v2_df.tail(1))

# for column_name in stock_portfolio_cumulative_returns_v2_df.tail(1):
#     print(f"{column_name}: {stock_portfolio_cumulative_returns_v2_df[column_name].tail(1).values - stock_portfolio_cumulative_returns_v2_df['S&P 500'].tail(1).values}")

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
daily_returns_with_portfolio_df.dropna(inplace=True)

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the daily standard deviations of all columns
daily_std_with_portfolio_df = daily_returns_with_portfolio_df.std()

# Calculate the annualized standard deviation (252 trading days)
annualized_std_with_portfolio_df = daily_std_with_portfolio_df * np.sqrt(252)

annualized_std_with_portfolio_df
# Out:
# AAPL         0.305283
# AXP          0.321512
# GS           0.271398
# KO           0.168783
# PLTR         0.721477
# S&P 500      0.203121
# Portfolio    0.270417
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_21_std_with_portfolio_df = daily_returns_with_portfolio_df.rolling(window=21).std()

# Plot rolling standard deviation
rolling_21_std_with_portfolio_df.plot(figsize=(20,10), title="21-day Rolling Standard Deviation").margins(x=0.025)

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
# Calculate the correlation
correlation_with_portfolio_df = daily_returns_with_portfolio_df.corr()

# Display the correlation matrix
sns.heatmap(correlation_with_portfolio_df, vmin=-1, vmax=1)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# 60-day rolling window

# 60-day rolling covariance
rolling_60_covariance_portfolio_sp500 = daily_returns_with_portfolio_df['Portfolio'].rolling(window=60).cov(daily_returns_with_portfolio_df['S&P 500'])

# 60-day rolling variance
rolling_60_variance = daily_returns_with_portfolio_df['S&P 500'].rolling(window=60).var()

# 60-day rolling beta
rolling_60_beta = rolling_60_covariance_portfolio_sp500 / rolling_60_variance

# Drop null values
rolling_60_beta.dropna(inplace=True)

# Plot the 60-day rolling Beta
rolling_60_beta.plot(figsize=(20,10), title="60-day Rolling Beta for the Portfolio")
# Out:
# <Axes: title={'center': '60-day Rolling Beta for the Portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios_with_portfolio = (daily_returns_with_portfolio_df.mean() * 252) / (daily_std_with_portfolio_df * np.sqrt(252))
sharpe_ratios_with_portfolio
# Out:
# AAPL         0.036471
# AXP         -0.055205
# GS          -0.289866
# KO          -0.112223
# PLTR         0.240409
# S&P 500     -0.216720
# Portfolio    0.051198
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_with_portfolio.plot.bar(title='Sharpe Ratios')
# Out:
# <Axes: title={'center': 'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# The portfolio performed pretty well relative to the market.  From 1/1/2022 and 9/30/2023, the S&P 500 was down roughly 10.6%, while the portfolio was only down 3.8%.  By far, the riskiest stock in the portfolio was Palantir (PLTR), which despite being down more than 60% of its initial value, eventually recovered to be in line with the other stocks.  Although the portfolio didn't have a great Sharpe ratio, it did have a much better Sharpe ratio than the market itself, so without a risk-free baseline to compare against (e.g., a treasury note), this seems like a reasonable result.  In the end, the portfolio outperformed the market and it had better risk-adjusted returns.
